# %%
import pyttsx3
import speech_recognition as sr
import requests
import geocoder
from geopy.distance import great_circle
import webbrowser
from bs4 import BeautifulSoup
import pyjokes
import datetime
import wikipedia
import pywhatkit
from playsound import playsound
from pywikihow import search_wikihow
from requests import get, request
import sys
import os
import smtplib
import speedtest
import pyautogui
from keyboard import press_and_release, press
import time  # Added for delay

# Initialize pyttsx3
engine = pyttsx3.init()
voices = engine.getProperty('voices')
# Set to male voice (index may vary)
engine.setProperty('voice', voices[0].id)
engine.setProperty('rate', 175)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source, 0, 4)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")

    except Exception as e:
        print("Say that again please...")
        return "None"
    return query

def My_Location():
    speak("Connecting to the cloud...")
    ip_add = requests.get('https://api.ipify.org').text
    url = 'https://get.geojs.io/v1/ip/geo/' + ip_add + '.json'
    geo_q = requests.get(url)
    geo_d = geo_q.json()
    state = geo_d['city']
    country = geo_d['country']
    print(f'{state}, {country}')
    speak(f"Your current location is {state}, {country}")

def GoogleMaps(Place):
    Url_Place = "https://www.google.com/maps/place/" + str(Place)
    webbrowser.open(url=Url_Place)
    speak(f"Here is the location of {Place} on Google Maps.")

def Dateconverter(Query):
    Date = Query.replace("and", "-")
    Date = Date.replace(" ", "")
    return str(Date)

def Temp():
    search = "temperature in my current location"
    url = f"https://www.google.com/search?q={search}"
    r = requests.get(url)
    data = BeautifulSoup(r.text, "html.parser")
    temperature = data.find("div", class_="BNeawe").text
    speak(f"The temperature outside is {temperature} Celsius.")
    speak("Do I have to tell you the temperature of another place?")
    next = takeCommand()
    if 'yes' in next:
        speak("Tell me the name of the place.")
        name = takeCommand()
        search = f"temperature in {name}"
        url = f"https://www.google.com/search?q={search}"
        r = requests.get(url)
        data = BeautifulSoup(r.text, "html.parser")
        temperature = data.find("div", class_="BNeawe").text
        speak(f"The temperature in {name} is {temperature} Celsius.")
    else:
        speak("No problem, sir.")

def WindowsAuto(command):
    query = str(command)
    if 'home screen' in query or 'minimize' in query:
        pyautogui.hotkey('win', 'm')
    elif 'show start' in query:
        pyautogui.press('win')
    elif 'open setting' in query:
        pyautogui.hotkey('win', 'i')
    elif 'open search' in query:
        pyautogui.hotkey('win', 's')
    elif 'screen shot' in query:
        pyautogui.hotkey('win', 'shift', 's')
    elif 'restore windows' in query:
        pyautogui.hotkey('win', 'shift', 'm')

def YouTubeAuto(command):
    query = str(command)
    time.sleep(2)  # Added delay to ensure the page is loaded
    if 'pause' in query or 'resume' in query:
        pyautogui.press('space')
    elif 'full screen' in query:
        pyautogui.press('f')
    elif 'film screen' in query:
        pyautogui.press('t')
    elif 'skip' in query:
        pyautogui.press('l')
    elif 'back' in query:
        pyautogui.press('j')
    elif 'increase' in query:
        pyautogui.hotkey('shift', '.')
    elif 'decrease' in query:
        pyautogui.hotkey('shift', ',')
    elif 'previous' in query:
        pyautogui.hotkey('shift', 'p')
    elif 'next' in query:
        pyautogui.hotkey('shift', 'n')
    elif 'mute' in query or 'unmute' in query:
        pyautogui.press('m')

def sign_off():
    speak("Goodbye and thank you for using me! Signing off here, Jaypea.")
    print("Goodbye and thank you for using me! Signing off here, Jaypea.")

def main():
    speak("Hello, I am your personal assistant Jaypea. How may I help you today?")
    
    while True:
        command = takeCommand().lower()

        if 'open youtube' in command:
            speak("Opening YouTube")
            webbrowser.open("https://www.youtube.com")
            speak("Which video would you like to play?")
            video = takeCommand()
            speak(f"Searching for {video} on YouTube.")
            pywhatkit.playonyt(video)
        elif 'my location' in command:
            My_Location()
        elif 'google maps' in command:
            speak("What place should I look up?")
            place = takeCommand()
            GoogleMaps(place)
        elif 'convert date' in command:
            speak("Please tell me the date to convert.")
            query = takeCommand()
            date = Dateconverter(query)
            speak(f"The converted date is {date}")
        elif 'temperature' in command:
            Temp()
        elif 'windows' in command:
            WindowsAuto(command)
        elif 'youtube' in command:
            YouTubeAuto(command)
        elif 'exit' in command or 'goodbye' in command:
            sign_off()
            break

if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognizing...
# User said: exit
#
# Goodbye and thank you for using me! Signing off here, Jaypea.

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import os
import speedtest
import webbrowser
from PIL import Image
from io import BytesIO
import requests  # Make sure you have 'requests' installed

# Initialize the text-to-speech engine
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Set to male voice
engine.setProperty('rate', 175)

def speak(audio):
    """Speaks the given audio string."""
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    """Greets the user based on the time of the day."""
    hour = int(datetime.datetime.now().hour)
    if 0 <= hour < 12:
        speak("Good Morning, sir!")
    elif 12 <= hour < 18:
        speak("Good Afternoon, sir!")
    else:
        speak("Good Evening, sir!")
    speak("Please tell me how may I help you")

def takeCommand():
    """Listens for the user's voice command."""
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source, 0, 4)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-us')
        print(f"User said: {query}\n")
    except Exception:
        print("Say that again please...")
        return "None"
    return query

def executeTask(query):
    """Executes the task based on the user's command."""
    if 'tell me about' in query:
        handle_google_search(query)
    elif 'the time' in query or 'show time' in query:
        tell_time()
    elif 'check internet speed' in query:
        check_internet_speed()
    elif 'open file' in query:
        open_file_from_computer()
    elif 'open google chrome' in query:
        open_google_chrome()
    elif 'download image' in query:
        download_image()
    elif 'exit' in query or 'goodbye' in query:
        speak("Goodbye and thank you for using me!")
        exit()

def handle_google_search(query):
    """Handles Google search queries."""
    speak('Searching Google... please wait')
    query = query.replace("tell me about", "").strip()
    if query:
        chrome_path = 'C:/Program Files/Google/Chrome/Application/chrome.exe %s'
        webbrowser.get(chrome_path).open(f'https://www.google.com/search?q={query}')
        speak(f"Opening Google Chrome to search for {query}")
    else:
        speak("I didn't get what you want to search for. Please try again.")

def tell_time():
    """Tells the current time."""
    strTime = datetime.datetime.now().strftime("%H:%M:%S")
    speak(f"Sir, the time is {strTime}")

def check_internet_speed():
    """Checks and speaks the internet speed."""
    try:
        wifi = speedtest.Speedtest()
        download_speed = wifi.download() / 1048576  # Convert to Mbps
        upload_speed = wifi.upload() / 1048576      # Convert to Mbps
        speak(f"Wifi download speed is {download_speed:.2f} MB per second")
        speak(f"Wifi upload speed is {upload_speed:.2f} MB per second")
    except speedtest.ConfigRetrievalError:
        speak("I couldn't retrieve the internet speed. Please try again later.")
    except Exception as e:
        speak("An error occurred while checking the internet speed.")

def open_file_from_computer():
    """Opens a specified file from common directories."""
    speak("Please tell me the file name to open.")
    file_name = takeCommand().lower()
    if file_name != 'none':
        common_dirs = [os.path.expanduser("~\\Documents"), os.path.expanduser("~\\Desktop")]
        found = False
        
        for directory in common_dirs:
            if os.path.exists(directory):
                files = os.listdir(directory)
                matching_files = [f for f in files if file_name in f.lower()]
                if matching_files:
                    os.startfile(os.path.join(directory, matching_files[0]))
                    speak(f"Opening {matching_files[0]}")
                    found = True
                    break
        
        if not found:
            speak("No matching files found in common directories.")
    else:
        speak("No file name was specified.")

def open_google_chrome():
    """Opens Google Chrome."""
    chrome_path = 'C:/Program Files/Google/Chrome/Application/chrome.exe %s'
    webbrowser.get(chrome_path).open('https://www.google.com')

def download_image():
    """Downloads an image from a URL provided by the user."""
    speak("Please tell me the image URL to download.")
    image_url = takeCommand().lower()
    
    if image_url != 'none':
        try:
            response = requests.get(image_url)
            response.raise_for_status()  # Check if the request was successful
            img = Image.open(BytesIO(response.content))
            file_path = os.path.expanduser("~\\Pictures\\downloaded_image.jpg")
            img.save(file_path)
            speak(f"Image downloaded and saved as {file_path}.")
            img.show()
        except requests.exceptions.RequestException:
            speak("Sorry, I couldn't download the image. Please check the URL and try again.")
        except Exception as e:
            speak("An error occurred while saving the image.")
            print(f"Error: {e}")
    else:
        speak("No URL was provided.")

def main():
    wishMe()
    while True:
        query = takeCommand().lower()
        if query == "none":
            continue
        executeTask(query)

if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognizing...
# Say that again please...
# Listening...
# Recognizing...
# User said: tell me about arduino
#
# Listening...
# Recognizing...
# User said: download image
#
# Listening...
# Recognizing...
# User said: image URL is download.jpg
#
# Listening...
# Recognizing...
# User said: tell me the time
#
# Listening...
# Recognizing...
# User said: open files from computer
#
# Listening...
# Recognizing...
# User said: patterns
#
# Listening...
# Recognizing...
# User said: open desktop
#
# Listening...
# Recognizing...
# User said: desktop
#
# Listening...
# Recognizing...
# User said: open files
#
# Listening...
# Recognizing...
# User said: best top
#
# Listening...
# Recognizing...
# User said: exit
#
# Listening...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 39, in takeCommand()
#      38     r.pause_threshold = 1
# ---> 39     audio = r.listen(source, 0, 4)
#      41 try:
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\anaconda3\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# OSError: [Errno -9999] Unanticipated host error
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 156
#     153         executeTask(query)
#     155 if __name__ == "__main__":
# --> 156     main()
#
# Cell In[9], line 150, in main()
#     148 wishMe()
#     149 while True:
# --> 150     query = takeCommand().lower()
#     151     if query == "none":
#     152         continue
#
# Cell In[9], line 36, in takeCommand()
#      34 """Listens for the user's voice command."""
#      35 r = sr.Recognizer()
# ---> 36 with sr.Microphone() as source:
#      37     print("Listening...")
#      38     r.pause_threshold = 1
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:189, in Microphone.__exit__(self, exc_type, exc_value, traceback)
#     187 def __exit__(self, exc_type, exc_value, traceback):
#     188     try:
# --> 189         self.stream.close()
#     190     finally:
#     191         self.stream = None
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:204, in Microphone.MicrophoneStream.close(self)
#     201 def close(self):
#     202     try:
#     203         # sometimes, if the stream isn't stopped, closing the stream throws an exception
# --> 204         if not self.pyaudio_stream.is_stopped():
#     205             self.pyaudio_stream.stop_stream()
#     206     finally:
#
# File ~\anaconda3\Lib\site-packages\pyaudio\__init__.py:515, in PyAudio.Stream.is_stopped(self)
#     510 def is_stopped(self):
#     511     """Returns whether the stream is stopped.
#     512
#     513     :rtype: bool
#     514     """
# --> 515     return pa.is_stream_stopped(self._stream)
#
# OSError: [Errno -9988] Stream closed

# %%
import pyttsx3
import speech_recognition as sr
import random

# Initialize the text-to-speech engine
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Set to male voice
engine.setProperty('rate', 178)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        r.energy_threshold = 300
        audio = r.listen(source, 0, 4)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"You said: {query}\n")
    except Exception as e:
        print("Say that again, please.")
        return "None"
    return query

def sign_off():
    speak("Goodbye and thank you for playing! Signing off here, Jaypea.")
    print("Goodbye and thank you for playing! Signing off here, Jaypea.")

def game_play():
    speak("Let's play Rock, Paper, Scissors!")
    print("LETS PLAYYYYYYYYYYYYYY")
    
    i = 0
    Me_score = 0
    Com_score = 0
    choices = ("rock", "paper", "scissors")

    while i < 5:
        com_choose = random.choice(choices)
        query = takeCommand().lower()

        if query == "goodbye":
            sign_off()
            return  # Exit the function to end the game

        if query == "rock":
            if com_choose == "rock":
                speak("Rock")
                print(f"Score: ME: {Me_score} | COM: {Com_score}")
            elif com_choose == "paper":
                speak("Paper")
                Com_score += 1
                print(f"Score: ME: {Me_score} | COM: {Com_score}")
            else:
                speak("Scissors")
                Me_score += 1
                print(f"Score: ME: {Me_score} | COM: {Com_score}")

        elif query == "paper":
            if com_choose == "rock":
                speak("Rock")
                Me_score += 1
                print(f"Score: ME: {Me_score} | COM: {Com_score}")
            elif com_choose == "paper":
                speak("Paper")
                print(f"Score: ME: {Me_score} | COM: {Com_score}")
            else:
                speak("Scissors")
                Com_score += 1
                print(f"Score: ME: {Me_score} | COM: {Com_score}")

        elif query in ["scissors", "scissor"]:
            if com_choose == "rock":
                speak("Rock")
                Com_score += 1
                print(f"Score: ME: {Me_score} | COM: {Com_score}")
            elif com_choose == "paper":
                speak("Paper")
                Me_score += 1
                print(f"Score: ME: {Me_score} | COM: {Com_score}")
            else:
                speak("Scissors")
                print(f"Score: ME: {Me_score} | COM: {Com_score}")

        else:
            speak("Invalid choice. Please choose rock, paper, or scissors.")
            continue

        i += 1

    # Final score
    speak(f"Final Score: ME: {Me_score} | COM: {Com_score}")
    print(f"FINAL SCORE: ME: {Me_score} | COM: {Com_score}")

    # Sign-off message
    sign_off()

# Call the game function to start
game_play()

# %%
import requests
import os
from PIL import Image
import pyttsx3
import sys
import time
import webbrowser
import speech_recognition as sr
from datetime import datetime

# Initialize the text-to-speech engine
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)  # Set to male voice
engine.setProperty('rate', 172)

def speak(audio):
    """Convert text to speech."""
    engine.say(audio)
    engine.runAndWait()

def fetch_nasa_apod(date):
    """Fetch Astronomy Picture of the Day (APOD) from NASA API."""
    api_key = "7ZXkdMVvFEKJOSYUBke8DLZhKA6Hs32BQFiCwGl7"
    url = "https://api.nasa.gov/planetary/apod"
    params = {'api_key': api_key, 'date': date}

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()

        title = data['title']
        explanation = data['explanation']
        media_type = data['media_type']
        url = data['url']
        return title, explanation, media_type, url
    except requests.exceptions.RequestException as e:
        speak("Sorry, I couldn't fetch data from NASA.")
        print(f"Error: {e}")
        return None, None, None, None

def save_and_show_image(image_url, file_name):
    """Download and display image."""
    try:
        image_response = requests.get(image_url)
        image_response.raise_for_status()

        with open(file_name, 'wb') as file:
            file.write(image_response.content)

        # Show the image
        img = Image.open(file_name)
        img.show()
    except requests.exceptions.RequestException as e:
        speak("Sorry, I couldn't download the image.")
        print(f"Error: {e}")
    except Exception as e:
        speak("An error occurred while displaying the image.")
        print(f"Error: {e}")

def search_in_chrome(query):
    """Search for a query in Chrome."""
    chrome_path = 'C:/Program Files/Google/Chrome/Application/chrome.exe %s'
    try:
        webbrowser.get(chrome_path).open(f'https://www.google.com/search?q={query}')
    except webbrowser.Error as e:
        speak("Failed to open Chrome.")
        print(f"Error: {e}")

def NasaNews(date):
    """Get NASA APOD information and show it."""
    speak("Connecting to NASA's cloud...")

    title, explanation, media_type, url = fetch_nasa_apod(date)
    if title and explanation and url:
        speak(f"Title: {title}")
        speak(f"According to the space station: {explanation}")

        # Perform a search in Chrome for the title
        search_in_chrome(title)

        if media_type == 'image':
            file_name = f"Nasa_{date}.jpg"
            save_and_show_image(url, file_name)
        elif media_type == 'video':
            speak("Today's APOD is a video. I will open the link for you.")
            try:
                os.system(f'start {url}')  # This will open the video in the default web browser
            except Exception as e:
                speak("Failed to open the video.")
                print(f"Error: {e}")
        else:
            speak("The media type is not supported.")
    else:
        speak("Failed to retrieve NASA's Astronomy Picture of the Day.")

def listen_for_command():
    """Listen for and process voice commands."""
    recognizer = sr.Recognizer()
    mic = sr.Microphone()

    with mic as source:
        speak("Listening for commands.")
        audio = recognizer.listen(source)

    try:
        command = recognizer.recognize_google(audio).lower()
        speak(f"You said: {command}")
        print(f"Recognized command: {command}")  # Debugging line

        if "fetch nasa apod for today" in command:
            date = datetime.now().strftime("%Y-%m-%d")
            NasaNews(date)
        elif "fetch nasa apod for" in command:
            date = command.split("fetch nasa apod for ")[1]
            NasaNews(date)
        else:
            speak("Command not recognized.")
    except sr.UnknownValueError:
        speak("Sorry, I didn't catch that. Please repeat.")
    except sr.RequestError:
        speak("Sorry, I'm having trouble with the speech recognition service.")

def exit_program():
    """Handle the exit process."""
    speak("Goodbye and thank you for using the program! Have a great day!")
    sys.exit()

def main():
    while True:
        listen_for_command()
        # Wait before listening again to avoid rapid repeats
        time.sleep(5)

if __name__ == "__main__":
    main()
# Out:
# Recognized command: search for suhani
# Recognized command: nasa a p o d information
# Recognized command: connect to nasa cloud
# Exception ignored in: <function BSTR.__del__ at 0x000001A5F142CEA0>
# Traceback (most recent call last):
#   File "C:\Users\simba\anaconda3\Lib\site-packages\comtypes\_post_coinit\bstr.py", line 16, in __del__
#     def __del__(self, _free=windll.oleaut32.SysFreeString):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 137
#     134         time.sleep(5)
#     136 if __name__ == "__main__":
# --> 137     main()
#
# Cell In[5], line 132, in main()
#     130 def main():
#     131     while True:
# --> 132         listen_for_command()
#     133         # Wait before listening again to avoid rapid repeats
#     134         time.sleep(5)
#
# Cell In[5], line 105, in listen_for_command()
#     103 with mic as source:
#     104     speak("Listening for commands.")
# --> 105     audio = recognizer.listen(source)
#     107 try:
#     108     command = recognizer.recognize_google(audio).lower()
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:491, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     488 if timeout and elapsed_time > timeout:
#     489     raise WaitTimeoutError("listening timed out while waiting for phrase to start")
# --> 491 buffer = source.stream.read(source.CHUNK)
#     492 if len(buffer) == 0: break  # reached end of the stream
#     493 frames.append(buffer)
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\anaconda3\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
